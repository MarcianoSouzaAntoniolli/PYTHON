# %%
# entrada
nome = input ("digite o seu NOME: ")
sbnome = input ("digite o seu SOBRENOME: ")

#prodessamento dos dados
resultato = "ola, " + nome + " "+ sbnome

# saida dos dados
print (resultato+ '"SEJA BEM VINDO!!!"' )
# Out:
# digite o seu NOME: marciano
# digite o seu SOBRENOME: antoniolli
# ola, marciano antoniolli"SEJA BEM VINDO!!!"
