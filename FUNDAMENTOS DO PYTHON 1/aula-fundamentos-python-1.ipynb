# %% [markdown]
# Exercício 2 Faça um programa que peça dois números inteiros. Imprima a soma desses dois números na tela.

# %%
a         = int (input("informe numero 01 :" ))
b         = int (input("informe numero 02 :" ))
resultado = a + b
print("O resultado da soma é :",resultado )
# Out:
# informe numero 01 :10
# informe numero 02 :20
# O resultado da soma é : 30

# %% [markdown]
# Exercício 3 Escreva um programa que leia um valor em metros e o exiba convertido em milímetros.

# %%
a         = float (input("informe um valor em metros :" ))
resultado = a * 1000
print("O valor a qtd de ",a," metros em milimetro e ", int(resultado))
# Out:
# informe um valor em metros :1
# O valor a qtd de  1.0  metros em milimetro e  1000

# %% [markdown]
# Exercício 4 Escreva um programa que leia dois números, faça a subtração entre eles, mostre o resultado na tela.

# %%
a         = int (input("informe numero 01 :" ))
b         = int (input("informe numero 02 :" ))
resultado = a - b
print("O resultado da subtração- é :",resultado )
# Out:
# informe numero 01 :5
# informe numero 02 :2
# O resultado da subtração é : 3

# %% [markdown]
# Exercício 5 Faça um programa que solicite o preço de uma mercadoria e o percentual de desconto. Exiba o valor do desconto e o preço a pagar.

# %%
a         = float (input("Informe o preço da mercadoria :" ))
b         = float (input("informe o % desconto :" ))
desconto  = a * (b/100)
pagar     = a - desconto
print("Valor original R$: ",a, "Valor de desconto R$: ",desconto, "Valor a Pagar R$: ",pagar)
# Out:
# Informe o preço da mercadoria :100
# informe o % desconto :10
# Valor original R$:  100.0 Valor de desconto R$:  10.0 Valor a Pagar R$:  90.0

# %% [markdown]
# Exercício 6 Faça um programa que calcule o aumento de um salário. Ele deve solicitar o valor do salário e a porcentagem do aumento. Exiba o valor do aumento e o valor do novo salário.

# %%
a       = float (input("Informe o Valor do salário :" ))
b       = float (input("informe o % de aumento :" ))
aumento = a * (b/100)
novo_salario    = a + aumento
print("Valor original R$: ",a, "Valor do aumento R$: ",aumento, "Valor a Novo Salario R$: ",novo_salario)
# Out:
# Informe o Valor do salário :1000
# informe o % de aumento :2
# Valor original R$:  1000.0 Valor do aumento R$:  20.0 Valor a Novo Salario R$:  1020.0

# %% [markdown]
# Exercício 7 Escreva um programa que converta uma temperatura digitada em Graus Celsius em Graus Fahrenheit. A fórmula para essa conversão é: F=(9*C/5)+32 ou F=C*1.8+32

# %%
celsus = float (input("A Temperatura em ºC :" ))

f      = (celsus * 1.8)+32

print("Valor em Fahrenheit é : ",f)
# Out:
# A Temperatura em ºC :39
# Valor em Fahrenheit é :  102.2

# %% [markdown]
# Exercício 8 Faça um programa que solicite dois valores do tipo float e calcule a média, exiba o resultado na tela.

# %%
a = float (input("valor 01 :" ))
b = float (input("valor 02 2:" ))
media = (a + b)/2

print("Valor da media entre ",a, "e Valor ",b, " é ",media)
# Out:
# valor 01 :10
# valor 02 :20
# Valor da media entre  10.0 e Valor  20.0  é  15.0

# %% [markdown]
# Exercício 9 Faça um programa que solicite um valor e converta km/h em m/s. Exiba o resultado na tela.

# %%
a         = float (input("valor em KM/H :" ))
valor_mth = a * 1000
resultado = (valor_mth / 60 )/60

print("Valor de  ",a, "KM/H em M/S é",round(resultado,2))
# Out:
# valor em KM/H :1
# Valor de   1.0 KM/H em M/S é 0.28

# %%
Exercício 10 Escreva um programa que peça um valor inteiro, calcule a potenciação do valor elevado a segunda potência. Imprima na tela o resultado.

# %%
a         = int (input("valor 1:" ))

resultado = (a**2 )

print("Valor  é",resultado)
# Out:
# valor 1:9
# Valor  é 81

# %% [markdown]
# Exercício 11 Construa um algoritmo que leia o nome e sobrenome e mostre na tela o nome concatenado com o sobrenome.

# %%
a     = input("INFORME O NOME:" )
b     = input("INFORME O SOBRENOME:" )


print( "Meu nome: " +a +" " +b)
# Out:
# INFORME O NOME:marciano
# INFORME O SOBRENOME:moreira de souza
# Meu nome: marciano moreira de souza

# %% [markdown]
# Exercício 12 Faça um programa que realize a soma, subtração, multiplicação e divisão a partir da entrada de dois números, mostre todos os resultados na tela.

# %%
valor_a = int(input("Digite o valor A: "));
valor_b = int(input("Digite o valor B: "));

soma    = round(valor_a + valor_b,2);
subtr   = round(valor_a - valor_b,2);
divisao = round(valor_a / valor_b,2);
multipl = round(valor_a * valor_b,2);

print(f"este e o resultado da soma:  {int(soma)}");
print(f"este e o resultado da subtração:  {int(subtr)}");
print(f"este e o resultado da divisao:  {int(divisao)}");
print(f"este e o resultado multiplicacao:  {int(multipl)}");
# Out:
# Digite o valor A: 5
# Digite o valor B: 5
# este e o resultado da soma:  10
# este e o resultado da subtração:  0
# este e o resultado da divisao:  1
# este e o resultado multiplicacao:  25

# %% [markdown]
# Exercício 13 Faça um programa que calcule o IMC(Índice de Massa Corporal) e mostre o resultado na tela, utilize a tabela de interpretação do IMC em anexo, e exiba a Classificação e o Grau de Obesidade. A fórmula para o calculo é: IMC=peso/(altura * altura).

# %%
peso    = float(input("INFOME SE PESO: "));
altura  = float(input("INFORME SUA ALTURA: "));

imc     = peso / (altura*altura)

print(f"seu imc é :  {float(imc)}");
# Out:
# INFOME SE PESO: 75
# INFORME SUA ALTURA: 1.65
# seu imc é :  27.548209366391188

# %% [markdown]
# Exercício 14 Faça um algoritmo que leia três notas de um aluno e calcule a média final deste aluno.

# %%
nota1 = float (input("NOTA 01:" ))
nota2 = float (input("NOTA 02:" ))
nota3 = float (input("NOTA 03:" ))
media = (nota1 + nota2 + nota3)/3

print(f"Valor da media entre as 3 notas é {float(media)}")
# Out:
# NOTA 01:5
# NOTA 02:7
# NOTA 03:9
# Valor da media entre as 3 notas é 7.0

# %% [markdown]
# Exercício 15 Faça um algoritmo leia o valor e calcule a área de um quadrado, imprima o resultado na tela.

# %%
lado1 = float (input("NOTA 01:" ))
area  = lado1 **2
print(f"Area do quadrado é {float(area)}")
# Out:
# NOTA 01:2
# Area do quadrado é 4.0

# %% [markdown]
# Exercício 16 Faça um programa computacional que calcule a área de uma circunferência e exiba a medida da área calculada.

# %%
raio = float (input("informe o raio:" ))
pi = 3.14
circunferencia  = (2*raio) * pi
print(f"Area do circunferenci é {float(circunferencia)}")
# Out:
# informe o raio:2
# Area do circunferenci é 12.56

# %% [markdown]
# Exercício 17 Desenvolva um software que calcule o volume de uma lata de refrigerante imprimir o resultado na tela.

# %%
raio    = float (input("informe o raio:" ))
altura  = float (input("informe o altura:" ))
pi      = 3.14
volume  = ((2*raio) * pi) * altura2
print(f"volume é {float(volume)}")
# Out:
# informe o raio:2
# informe o altura:2
# volume é 25.12

# %% [markdown]
# Exercício 18 Elaborar um programa que leia um valor numérico inteiro, apresentar uma mensagem informativa se o valor fornecido é par ou ímpar.

# %%
numero = int(input ("Informe um Valor Interiro:"))
resto  = numero % 2
if resto == 0:
  print (numero,"é par");
else: print (numero,"é impar");
# Out:
# Informe um Valor Interiro:5
# 5 é impar

# %% [markdown]
# Exercício 19 Para ter acesso a fila preferencial você deve ser idoso, gestante ou cadeirante, faça um programa que peça um valor inteiro de 1 a 5 (1 Cadeirante, 2 Gestante, 3 Idoso, 4 Jovem, 5 Caçador de Pokémon) e imprima se a pessoa tem direito à fila prioritária, caso contrário imprima não tem direito a fila prioritária.

# %%
numero = int(input ("Informe um Valor Interiro:"))

if numero == 1:
  print (f"TEM direito a fila prioritária {numero} - CADEIRANTE");
elif numero == 2:
  print (f"TEM direito a fila prioritária {numero} - GESTANTE");
elif numero == 3:
  print (f"TEM direito a fila prioritária {numero} - IDOSO");
elif numero == 4:
  print (f"NÃO TEM direito a fila prioritária {numero} - JOVEM");
else: print (f"NÃO TEM direito a fila prioritária {numero} - CAÇADOR DE POCKEMON");
# Out:
# Informe um Valor Interiro:2
# TEM direito a fila prioritária 2 - GESTANTE

# %% [markdown]
# Exercício 20 Faça um programa que pergunte se seu animal de estimação está com fome, caso não estiver com fome imprimir: "Levar meu animalzinho para passear", caso contrário, perguntar se tem ração, caso sim imprimir: "Alimentar meu animalzinho" caso contrário imprimir: "Tenho que comprar ração".

# %%
resposta = str(input("SEU ANIMALZINHO ESTA COM FOME [S/N] ? :"))
if resposta == 'S' or resposta == 's':
  resposta2 = str(input("VOCE TEM RAÇÃO [S/N]? :"))
  if resposta2 == 'S' or resposta == 's':
    print (f"Alimentar meu animalzinho ");
  else:
    print (f"Tenho que comprar ração");
else :
  print ("Levar meu animalzinho para passear");
# Out:
# SEU ANIMALZINHO ESTA COM FOME [S/N] ? :s
# VOCE TEM RAÇÃO [S/N]? :s
# Alimentar meu animalzinho

# %% [markdown]
# Exercício 21 Desenvolver um programa que leia um valor numérico inteiro entre os valores 1 e 12 e apresentar por extenso o nome do mês correspondente ao valor entrado. Caso sejam fornecidos valores menores que 1 e maiores que 12, o programa deve apresentar a mensagem "Valor inválido". Utilizar neste exercício: Condicional, Lista, Tupla, ou Dicionário.

# %%
meses =["JANEIRO","FEVEREIRO","MARÇO","ABRIL","MAIO","JUNHO","JULHO","AGOSTO","SETEMBRO","OUTUBRO","NOVEMBRO","DEZEMBRO"]
mes_numero = int(input("NUMERO DO MES ENTRE 1 E 12 :"))

if mes_numero < 1 or mes_numero > 12:
   print (f"NUM INFORMADO IVALIDO INFORME O NUMERO CORRETO PARA CONTINUAR!! ");
   mes_numero = int(input("NUMERO DO MES ENTRE 1 E 12 :"))
   print(mese[mes_numero-1])
match mes_numero:
    case 1:
         print(meses[mes_numero-1])
    case 2:
         print(meses[mes_numero-1])
    case 3:
         print(meses[mes_numero-1])
    case 4:
         print(meses[mes_numero-1])
    case 5:
         print(meses[mes_numero-1])
    case 6:
         print(meses[mes_numero-1])
    case 7:
         print(meses[mes_numero-1])
    case 8:
         print(meses[mes_numero-1])
    case 9:
         print(meses[mes_numero-1])
    case 10:
         print(meses[mes_numero-1])
    case 11:
         print(meses[mes_numero-1])
    case 12:
         print(meses[mes_numero-1])
    case _:
        print("MES INVALIDO")
# Out:
# NUMERO DO MES ENTRE 1 E 12 :1
# JANEIRO

# %%
meses =["JANEIRO","FEVEREIRO","MARÇO","ABRIL","MAIO","JUNHO","JULHO","AGOSTO","SETEMBRO","OUTUBRO","NOVEMBRO","DEZEMBRO"]
mes_numero = int(input("NUMERO DO MES ENTRE 1 E 12 :"))
if mes_numero < 1 or mes_numero > 12:
  print("VALOR DIGITADO INVALIDO")
else: print(meses[mes_numero-1])
# Out:
# NUMERO DO MES ENTRE 1 E 12 :2
# FEVEREIRO

# %% [markdown]
# Exercício 22 Escreva um jogo da adivinhação que peça um número inteiro de 1 à 10, se o jogador adivinhar mostre a mensagem "Parabéns, você acertou!", caso contrário "Que pena você errou, tente outra vez".

# %%
import random
ADVINHADAR  = random.randint(1, 10);
numero      = False;

numero = int(input("NUMERO DO MES ENTRE 1 E 10 :"))

while numero != ADVINHADAR :
  numero = int(input("NUMERO DO MES ENTRE 1 E 10 :"))

print (f"VOCE ACERTOU O NUMERO!! O NUMERO CORRETO ERA {ADVINHADAR}")
# Out:
# NUMERO DO MES ENTRE 1 E 12 :6
# NUMERO DO MES ENTRE 1 E 12 :5
# NUMERO DO MES ENTRE 1 E 12 :4
# NUMERO DO MES ENTRE 1 E 12 :3
# NUMERO DO MES ENTRE 1 E 12 :2
# NUMERO DO MES ENTRE 1 E 12 :1
# NUMERO DO MES ENTRE 1 E 12 :7
# NUMERO DO MES ENTRE 1 E 12 :8
# NUMERO DO MES ENTRE 1 E 12 :9
# NUMERO DO MES ENTRE 1 E 12 :10
# VOCE ACERTOU O NUMERO!! O NUMERO CORRETO ERA 10

# %%
a = 10
b = 20
c = 30
d = 40

if a > b or a > c or b > c :
  print ("VERDADE")
elif d < a :
  print("MAIS OUTRA VERDADE")
else :
  print("MAIS OUTRO VERDADE")
# Out:
# MAIS OUTRO VERDADE

# %%
numbers = [111, 7, 2, 1]
print(numbers[-1])
# Out:
# 1

# %%
my_list = [10, 1, 8, 3, 5]

my_list[0], my_list[4] = my_list[4], my_list[0]
my_list[1], my_list[3] = my_list[3], my_list[1]

print(my_list)
# Out:
# [5, 3, 8, 1, 10]
