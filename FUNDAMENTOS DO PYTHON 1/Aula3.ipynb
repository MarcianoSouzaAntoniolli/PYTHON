# %%
print("\nIsso é tudo, pessoal!")
# Out:
# Isso é tudo, pessoal!

# %%
x = float(input("Digite o valor para x: "))

# Escreva seu código aqui.

print("y =", y)

# %%
x = input("Digite um número: ") # O usuário digita 2
print(type(x))
# Out:
# Digite um número: 2
# <class 'str'>

# %%
x = int(input("Digite um número: ")) # O usuário digita 2
print(x * "5")
# Out:
# Digite um número: 2
# 55

# %%
r = 1/1
print (type(r),"o resultado é: "  ,r)
# Out:
# <class 'float'> o resultado é:  1.0

# %%
1 // 2 * 3
# Out:
# 0

# %%
#pegunta 11
x = 1
y = 2
z = x
x = y
y = z
print(x, y)
# Out:
# 2 1

# %%
#pergunta 12
x = input()
y = input()
print(x + y)
# Out:
# 2
# 4
# 24

# %%
x = int(input())
y = int(input())

x = x // y
y = y // x

print(y)
# Out:
# 2
# 4
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-15-94a8a979586c> in <cell line: 0>()
#       3
#       4 x = x // y
# ----> 5 y = y // x
#       6
#       7 print(y)
#
# ZeroDivisionError: integer division or modulo by zero

# %%
x = int(input())
y = int(input())

x = x / y
y = y / x

print(y)
# Out:
# 2
# 4
# 8.0

# %%
x = int(input())
y = int(input())

x = x % y
x = x % y
y = y % x

print(y)
# Out:
# 11
# 4
# 1

# %%
x = input()
y = int(input())

print(x * y)
# Out:
# 3
# 6
# 333333

# %%
z = y = x = 1
print(x, y, z, sep='*')
# Out:
# 1*1*1

# %%
x = 1 / 2 + 3 // 3 + 4 ** 2
print(x)
# Out:
# 17.5
